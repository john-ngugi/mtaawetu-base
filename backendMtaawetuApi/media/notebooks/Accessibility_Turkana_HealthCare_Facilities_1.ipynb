# %% [markdown]
# **Accessibility Modelling**
#
# Using the R5Py library to calculate the travel time matrix and analyze the accessibility of urban amenities
# The R5Py library, is a Python wrapper for the R5 routing engine. R5 is a multimodal routing engine that can be used to calculate travel times between locations in a city using different modes of transport, such as walking, cycling, and public transport. It is open-source, efficient and use real-time data and OpenStreetMap to provide accurate travel time estimates.
#
# R5Py calculates the travel time matrix between origins and destinations.

# %%
# You can use .explore() to interactively explore the data or .plot() to plot the data
# destinations_hospitals.plot()
Hospitals.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e0b87f44f98b0cbee33ff39bde089e6e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e0b87f44f98b0cbee33ff39bde089e6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e0b87f44f98b0cbee33ff39bde089e6e = L.map(
#                 &quot;map_e0b87f44f98b0cbee33ff39bde089e6e&quot;,
#                 {
#                     center: [3.2471249999688325, 35.30745000016742],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_e0b87f44f98b0cbee33ff39bde089e6e);
#
#
#
#
#
#             var tile_layer_b211e80629ecfd4bd2c2510e05c75c31 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b211e80629ecfd4bd2c2510e05c75c31.addTo(map_e0b87f44f98b0cbee33ff39bde089e6e);
#
#
#             map_e0b87f44f98b0cbee33ff39bde089e6e.fitBounds(
#                 [[1.186970000265376, 34.242899999935105], [5.307279999672289, 36.37200000039974]],
#                 {}
#             );
#
#
#         function geo_json_be9f3ea67dbd606b7e0549a816edd2a8_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_be9f3ea67dbd606b7e0549a816edd2a8_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_be9f3ea67dbd606b7e0549a816edd2a8_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_be9f3ea67dbd606b7e0549a816edd2a8_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_be9f3ea67dbd606b7e0549a816edd2a8_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_be9f3ea67dbd606b7e0549a816edd2a8.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_be9f3ea67dbd606b7e0549a816edd2a8_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_be9f3ea67dbd606b7e0549a816edd2a8 = L.geoJson(null, {
#                 onEachFeature: geo_json_be9f3ea67dbd606b7e0549a816edd2a8_onEachFeature,
#
#                 style: geo_json_be9f3ea67dbd606b7e0549a816edd2a8_styler,
#                 pointToLayer: geo_json_be9f3ea67dbd606b7e0549a816edd2a8_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_be9f3ea67dbd606b7e0549a816edd2a8_add (data) {
#             geo_json_be9f3ea67dbd606b7e0549a816edd2a8
#                 .addData(data);
#         }
#             geo_json_be9f3ea67dbd606b7e0549a816edd2a8_add({&quot;bbox&quot;: [34.242899999935105, 1.186970000265376, 36.37200000039974, 5.307279999672289], &quot;features&quot;: [{&quot;bbox&quot;: [35.59954000037078, 3.119420000033017, 35.59954000037078, 3.119420000033017], &quot;geometry&quot;: {&quot;coordinates&quot;: [35.59954000037078, 3.119420000033017], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Facility_N&quot;: &quot;Afya Bora Medical Clinic (Turkana Central)&quot;, &quot;id&quot;: 88}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [35.60968999989365, 3.10973000013945, 35.60968999989365, 3.10973000013945], &quot;geometry&quot;: {&quot;coordinates&quot;: [35.60968999989365, 3.1

# %% [markdown]
# ## Step 7: Accessibility Analysis

# %%
# Or instead, you can use explore for an interactive plot.
join.explore(column="Access_Health Care Facilities", scheme='natural_breaks',cmap="plasma")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_256618f7385dc3e01f965bc1b1bc5a63 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_256618f7385dc3e01f965bc1b1bc5a63&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_256618f7385dc3e01f965bc1b1bc5a63 = L.map(
#                 &quot;map_256618f7385dc3e01f965bc1b1bc5a63&quot;,
#                 {
#                     center: [2.7604643223813117, 35.28684341180259],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_256618f7385dc3e01f965bc1b1bc5a63);
#
#
#
#
#
#             var tile_layer_9fb28a92158718025ef618cfd4345efb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9fb28a92158718025ef618cfd4345efb.addTo(map_256618f7385dc3e01f965bc1b1bc5a63);
#
#
#             map_256618f7385dc3e01f965bc1b1bc5a63.fitBounds(
#                 [[1.1780074456794885, 34.313137637111346], [4.3429211990831345, 36.26054918649383]],
#                 {}
#             );
#
#
#         function geo_json_f468831e5aef78c89101c4aa57b2df20_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;40&quot;: case &quot;47&quot;: case &quot;48&quot;: case &quot;49&quot;: case &quot;67&quot;: case &quot;68&quot;: case &quot;82&quot;: case &quot;102&quot;: case &quot;113&quot;: case &quot;118&quot;: case &quot;119&quot;: case &quot;120&quot;: case &quot;121&quot;: case &quot;122&quot;: case &quot;123&quot;: case &quot;124&quot;: case &quot;125&quot;: case &quot;126&quot;: case &quot;127&quot;: case &quot;128&quot;: case &quot;129&quot;: case &quot;130&quot;: case &quot;131&quot;: case &quot;132&quot;: case &quot;133&quot;: case &quot;134&quot;: case &quot;135&quot;: case &quot;136&quot;: case &quot;137&quot;: case &quot;138&quot;: case &quot;139&quot;: case &quot;140&quot;: case &quot;141&quot;: case &quot;142&quot;: case &quot;143&quot;: case &quot;144&quot;: case &quot;145&quot;: case &quot;146&quot;: case &quot;147&quot;: case &quot;148&quot;: case &quot;149&quot;: case &quot;150&quot;: case &quot;151&quot;: case &quot;152&quot;: case &quot;153&quot;: case &quot;154&quot;: case &quot;155&quot;: case &quot;156&quot;: case &quot;157&quot;: case &quot;158&quot;: case &quot;159&quot;: case &quot;160&quot;: case &quot;161&quot;: case &quot;162&quot;: case &quot;163&quot;: case &quot;164&quot;: case &quot;165&quot;: case &quot;166&quot;: case &quot;167&quot;: case &quot;168&quot;: case &quot;169&quot;: case &quot;170&quot;: case &quot;171&quot;: case &quot;172&quot;: case &quot;173&quot;: case &quot;174&quot;: case &quot;175&quot;: case &quot;176&quot;: case &quot;177&quot;: case &quot;178&quot;: case &quot;179&quot;: case &quot;180&quot;: case &quot;181&quot;: case &quot;183&quot;: case &quot;184&quot;: case &quot;185&quot;: case &quot;186&quot;: case &quot;187&quot;: case &quot;188&quot;: case &quot;189&quot;: case &quot;190&quot;: case &quot;191&quot;: case &quot;192&quot;: case &quot;193&quot;: case &quot;194&quot;: case &quot;195&quot;: case &quot;196&quot;: case &quot;197&quot;: case &quot;198&quot;: case &quot;199&quot;: case &quot;201&quot;: case &quot;203&quot;: case &quot;205&quot;: case &quot;206&quot;: case &quot;208&quot;: case &quot;211&quot;: case &quot;212&quot;: case &quot;213&quot;: case &quot;214&quot;: case &quot;215&quot;: case &quot;219&quot;: case &quot;220&quot;: case &quot;221&quot;: case &quot;222&quot;: case &quot;225&quot;: case &quot;226&quot;: case &quot;227&quot;: case &quot;228&quot;: case &quot;229&quot;: case &quot;234&quot;: case &quot;235&quot;: case &quot;236&quot;: case &quot;237&quot;: case &quot;238&quot;: case &quot;239&quot;: case &quot;240&quot;: case &quot;249&quot;: case &quot;250&quot;: case &quot;251&quot;: case &quot;252&quot;: case &quot;253&quot;: case &quot;254&quot;: case &quot;255&quot;: case &quot;256&quot;: case &quot;257&quot;: case &quot;258&quot;: case &quot;259&quot;: case &quot;266&quot;: case &quot;267&quot;: case &quot;268&quot;: case &quot;269&quo
